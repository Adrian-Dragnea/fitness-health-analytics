# %%
from pathlib import Path
import yaml
import pandas as pd

with open("../config/local.yaml", "r") as f:
    config = yaml.safe_load(f)

RAW_PATH = Path(config["paths"]["raw_data"])
PROCESSED_PATH = Path(config["paths"]["processed_data"])

RAW_PATH, PROCESSED_PATH
# Out:
# (PosixPath('/mnt/nas/Projects/fitness-health-analytics/data/raw'),
#  PosixPath('/mnt/nas/Projects/fitness-health-analytics/data/processed'))

# %%
list(RAW_PATH.iterdir())
# Out:
# [PosixPath('/mnt/nas/Projects/fitness-health-analytics/data/raw/Fitness_Health_Tracking_Dataset_with_Missing_Values.xlsx')]

# %%
df = pd.read_excel(RAW_PATH / "Fitness_Health_Tracking_Dataset_with_Missing_Values.xlsx")

# %%
df.columns
# Out:
# Index(['User_ID', 'Full Name', 'Date', 'Age', 'Gender', 'Height (cm)',
#        'Weight (kg)', 'Steps_Taken', 'Calories_Burned', 'Hours_Slept',
#        'Water_Intake (Liters)', 'Active_Minutes', 'Heart_Rate (bpm)',
#        'Workout_Type', 'Stress_Level (1-10)', 'Mood'],
#       dtype='object')

# %%
df.shape
df.info()
df.describe(include="all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36500 entries, 0 to 36499
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   User_ID                36500 non-null  int64
#  1   Full Name              36500 non-null  object
#  2   Date                   36500 non-null  datetime64[ns]
#  3   Age                    36500 non-null  int64
#  4   Gender                 36500 non-null  object
#  5   Height (cm)            36500 non-null  int64
#  6   Weight (kg)            36500 non-null  int64
#  7   Steps_Taken            36500 non-null  int64
#  8   Calories_Burned        36500 non-null  int64
#  9   Hours_Slept            32841 non-null  float64
#  10  Water_Intake (Liters)  31099 non-null  float64
#  11  Active_Minutes         34633 non-null  float64
#  12  Heart_Rate (bpm)       34668 non-null  float64
#  13  Workout_Type           27308 non-null  object
# ...

# %%
df.head()
# Out:
#    User_ID      Full Name       Date  Age  Gender  Height (cm)  Weight (kg)  \
# 0        1  Sara Martinez 2023-01-01   19  Female          191           80
# 1        1  Sara Martinez 2023-01-02   19  Female          191           80
# 2        1  Sara Martinez 2023-01-03   19  Female          191           80
# 3        1  Sara Martinez 2023-01-04   19  Female          191           80
# 4        1  Sara Martinez 2023-01-05   19  Female          191           80
#
#    Steps_Taken  Calories_Burned  Hours_Slept  Water_Intake (Liters)  \
# 0        11405             1862     7.021201               3.440508
# 1         7010             1806          NaN               3.103590
# 2        18942             2274     8.167817               3.814843
# 3        13778             2656     7.453552               3.508636
# 4        10247             3571     5.132654                    NaN
#
#    Active_Minutes  Heart_Rate (bpm) Workout_Type  Stress_Level (1-10)     Mood
# ...

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Workout_Type             9192
# Water_Intake (Liters)    5401
# Hours_Slept              3659
# Active_Minutes           1867
# Heart_Rate (bpm)         1832
# User_ID                     0
# Date                        0
# Full Name                   0
# Steps_Taken                 0
# Weight (kg)                 0
# Height (cm)                 0
# Gender                      0
# Age                         0
# Calories_Burned             0
# Stress_Level (1-10)         0
# Mood                        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.hist(figsize=(12, 8))
# Out:
# array([[<Axes: title={'center': 'User_ID'}>,
#         <Axes: title={'center': 'Date'}>,
#         <Axes: title={'center': 'Age'}>],
#        [<Axes: title={'center': 'Height (cm)'}>,
#         <Axes: title={'center': 'Weight (kg)'}>,
#         <Axes: title={'center': 'Steps_Taken'}>],
#        [<Axes: title={'center': 'Calories_Burned'}>,
#         <Axes: title={'center': 'Hours_Slept'}>,
#         <Axes: title={'center': 'Water_Intake (Liters)'}>],
#        [<Axes: title={'center': 'Active_Minutes'}>,
#         <Axes: title={'center': 'Heart_Rate (bpm)'}>,
#         <Axes: title={'center': 'Stress_Level (1-10)'}>]], dtype=object)

# %%
df.Workout_Type.value_counts()
# Out:
# Workout_Type
# Yoga        9222
# Cardio      9048
# Strength    9038
# Name: count, dtype: int64

# %%
df.Mood.value_counts()
# Out:
# Mood
# Sad         9284
# Neutral     9115
# Happy       9061
# Stressed    9040
# Name: count, dtype: int64
